# %%
import numpy as np
import pandas as pd
np.random.seed(1)

# %%
full_labels = pd.read_csv('data/dragon_labels.csv')

# %%
full_labels
# Out:
#         filename  width  height   class  xmin  ymin  xmax  ymax
# 0      d_(1).png    126     160  dragon    30    53    99   110
# 1     d_(10).png    396     336  dragon   164   107   254   183
# 2    d_(100).png    348     344  dragon   177   127   277   217
# 3    d_(101).png    512     520  dragon    73   199   216   323
# 4    d_(102).png    396     342  dragon    86   139   150   196
# 5    d_(103).png    740     480  dragon   417    72   562   225
# 6    d_(104).png    512     520  dragon    74   203   215   327
# 7    d_(105).png    228     222  dragon    61    35   167   130
# 8    d_(106).png    396     390  dragon   148    69   304   182
# 9    d_(107).png    686     658  dragon    50    93   262   305
# 10   d_(108).png    586     562  dragon    98   205   243   322
# 11   d_(109).png    768     882  dragon   128   306   381   516
# 12    d_(11).png   1440    1144  dragon   664   639   781   744
# 13    d_(11).png   1440    1144  dragon  1103   452  1194   541
# 14    d_(11).png   1440    1144  dragon   268   473   366   558
# 15    d_(11).png   1440    1144  dragon   664   114   741   182
# 16    d_(11).png   1440    1144  dragon   337   322   398   395
# 17    d_(11).png   1440    1144  dragon   994   199  1071   273
# 18    d_(11).png   1440    1144  dragon  1049   329  1103   401
# 19    d_(11).png   1440    1144  dragon   379   214   443   275
# 20   d_(110).png    690     610  dragon    28   146   135   275
# 21   d_(111).png    912     704  dragon   422   454   500   526
# 22   d_(112).png    528     608  dragon   164    47   267   133
# 23   d_(113).png   2048    1396  dragon   829   361  1408   852
# 24   d_(114).png   1280    1280  dragon   326   247   941   808
# 25   d_(115).png   1440    1266  dragon   800   377  1041   598
# 26   d_(116).png    332     316  dragon   112   183   203   259
# 27   d_(117).png   1440    1292  dragon    24   149   151   279
# 28   d_(117).png   1440    1292  dragon   777    88  1000   337
# 29   d_(117).png   1440    1292  dragon   200  1111   292  1192
# ..           ...    ...     ...     ...   ...   ...   ...   ...
# 343   d_(66).png    710     114  dragon    41    26    98    88
# 344   d_(66).png    710     114  dragon   610    44   673    97
# 345   d_(67).png    350     152  dragon   213    38   292   111
# 346   d_(68).png    406     136  dragon   283    48   327    85
# 347   d_(69).png    360     326  dragon    46   140   102   195
# 348   d_(71).png    416     300  dragon   227    48   358   169
# 349   d_(72).png    368     368  dragon    55    50   175   164
# 350   d_(73).png    820     614  dragon   382   235   444   286
# 351   d_(74).png    332     304  dragon   146   117   196   161
# 352   d_(75).png    154     278  dragon    66   195   104   226
# 353   d_(76).png    232     116  dragon   119    34   169    77
# 354   d_(77).png    368     368  dragon   108    66   263   211
# 355    d_(8).png    396     390  dragon    12    88   138   212
# 356   d_(81).png   1000     970  dragon   313   376   526   596
# 357   d_(82).png    154     158  dragon    72    52   125   102
# 358   d_(83).png    164      98  dragon    24    18    69    55
# 359   d_(83).png    164      98  dragon    83    21   141    57
# 360   d_(84).png    260     168  dragon   102    82   145   115
# 361   d_(85).png    176     312  dragon    36   121   141   203
# 362   d_(86).png   1270    1308  dragon   480   901   766  1120
# 363   d_(88).png    960     688  dragon   499   124   792   387
# 364   d_(89).png    600     728  dragon   255   210   421   354
# 365    d_(9).png    998     668  dragon   146   266   404   513
# 366   d_(90).png    170     240  dragon    46    40    80    74
# 367   d_(91).png    480     342  dragon    97   144   225   256
# 368   d_(92).png    524     512  dragon   185   158   261   221
# 369   d_(94).png    240     168  dragon    73    19   135    79
# 370   d_(95).png    276     272  dragon    67    64   200   167
# 371   d_(96).png    200     204  dragon   102    90   162   144
# 372   d_(97).png    396     250  dragon   267   163   326   210
#
# [373 rows x 8 columns]

# %%
grouped = full_labels.groupby('filename')

# %%
grouped.apply(lambda x: len(x)).value_counts()
# Out:
# 1    322
# 2     12
# 3      3
# 5      2
# 8      1
# dtype: int64

# %% [markdown]
# ### split each file into a group in a list

# %%
gb = full_labels.groupby('filename')

# %%
grouped_list = [gb.get_group(x) for x in gb.groups]

# %%
len(grouped_list)
# Out:
# 340

# %%
train_index = np.random.choice(len(grouped_list), size=272, replace=False)
test_index = np.setdiff1d(list(range(340)), train_index)

# %%
len(train_index), len(test_index)
# Out:
# (272, 68)

# %%
# take first 200 files
train = pd.concat([grouped_list[i] for i in train_index])
test = pd.concat([grouped_list[i] for i in test_index])

# %%
len(train), len(test)
# Out:
# (298, 75)

# %%
train.to_csv('train_labels.csv', index=None)
test.to_csv('test_labels.csv', index=None)
